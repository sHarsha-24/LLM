# %%
sentence = "Machine learning and NLP are closely related"
word_tokens = sentence.split(" ")
print("Whitespace Tokens:")
print(word_tokens)
# Out:
# Whitespace Tokens:
# ['Machine', 'learning', 'and', 'NLP', 'are', 'closely', 'related']

# %%
word = "AItools"
characters = [char for char in word]
print("Character Level Tokens:")
print(characters)
# Out:
# Character Level Tokens:
# ['A', 'I', 't', 'o', 'o', 'l', 's']
