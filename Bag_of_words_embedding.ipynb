# %%
from sklearn.feature_extraction.text import CountVectorizer

# Sample corpus
corpus = [
    "apple banana mango",
    "banana orange",
    "apple orange banana"
]

# Create BoW vectorizer
vectorizer = CountVectorizer()

# Fit and transform
bow_matrix = vectorizer.fit_transform(corpus)

# Vocabulary
print("Vocabulary:", vectorizer.vocabulary_)

# BoW embedding for a new word or sentence
text = ["apple"]
embedding = vectorizer.transform(text)

print("BoW Embedding:", embedding.toarray())
# Out:
# Vocabulary: {'apple': 0, 'banana': 1, 'mango': 2, 'orange': 3}
# BoW Embedding: [[1 0 0 0]]
